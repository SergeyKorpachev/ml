# %%
import ROOT
from array import array
# Out:
# Welcome to JupyROOT 6.22/06

# %%
fRawData1 = "./data/data_other/gun_k0L_1gev_FTFP_BERT_10000evt_ILD_l5_v02steel.root"
fRawData2 = "./data/data_other/gun_k0L_2gev_FTFP_BERT_10000evt_ILD_l5_v02steel.root"
fRawData3 = "./data/data_other/gun_k0L_3gev_FTFP_BERT_10000evt_ILD_l5_v02steel.root"
fRawData4 = "./data/data_other/gun_k0L_4gev_FTFP_BERT_10000evt_ILD_l5_v02steel.root"

fRawData5 = "./data/gun_k0L_5gev_FTFP_BERT_10000evt_ILD_l5_v02steel.root"
fRawData10 = "./data/gun_k0L_10gev_FTFP_BERT_10000evt_ILD_l5_v02steel.root"
fRawData15 = "./data/gun_k0L_15gev_FTFP_BERT_10000evt_ILD_l5_v02steel.root"
fRawData20 = "./data/gun_k0L_20gev_FTFP_BERT_10000evt_ILD_l5_v02steel.root"
fRawData25 = "./data/gun_k0L_25gev_FTFP_BERT_10000evt_ILD_l5_v02steel.root"
fRawData30 = "./data/gun_k0L_30gev_FTFP_BERT_10000evt_ILD_l5_v02steel.root"
fRawData40 = "./data/gun_k0L_40gev_FTFP_BERT_10000evt_ILD_l5_v02steel.root"
fRawData50 = "./data/gun_k0L_50gev_FTFP_BERT_10000evt_ILD_l5_v02steel.root"
fRawData60 = "./data/gun_k0L_60gev_FTFP_BERT_10000evt_ILD_l5_v02steel.root"

fRawData70 = "./data/data_other/gun_k0L_70gev_FTFP_BERT_10000evt_ILD_l5_v02steel.root"
fRawData80 = "./data/data_other/gun_k0L_80gev_FTFP_BERT_10000evt_ILD_l5_v02steel.root"
fRawData90 = "./data/data_other/gun_k0L_90gev_FTFP_BERT_10000evt_ILD_l5_v02steel.root"


fRawData6 = "./data/data_other/gun_k0L_6gev_FTFP_BERT_10000evt_ILD_l5_v02steel.root"
fRawData8 = "./data/data_other/gun_k0L_8gev_FTFP_BERT_10000evt_ILD_l5_v02steel.root"
fRawData9 = "./data/data_other/gun_k0L_9gev_FTFP_BERT_10000evt_ILD_l5_v02steel.root"
fRawData12 = "./data/data_other/gun_k0L_12gev_FTFP_BERT_10000evt_ILD_l5_v02steel.root"
fRawData14 = "./data/data_other/gun_k0L_14gev_FTFP_BERT_10000evt_ILD_l5_v02steel.root"
fRawData16 = "./data/data_other/gun_k0L_16gev_FTFP_BERT_10000evt_ILD_l5_v02steel.root"
fRawData18 = "./data/data_other/gun_k0L_18gev_FTFP_BERT_10000evt_ILD_l5_v02steel.root"
fRawData35 = "./data/data_other/gun_k0L_35gev_FTFP_BERT_10000evt_ILD_l5_v02steel.root"
fRawData55 = "./data/data_other/gun_k0L_55gev_FTFP_BERT_10000evt_ILD_l5_v02steel.root"
fRawData65 = "./data/data_other/gun_k0L_65gev_FTFP_BERT_10000evt_ILD_l5_v02steel.root"

#fRawData = [fRawData5, fRawData10, fRawData15, fRawData20, fRawData25, fRawData30, fRawData40,
#            fRawData50, fRawData60]

fRawData = [fRawData1, fRawData2, fRawData3, fRawData4, fRawData5, fRawData6, fRawData8, fRawData9, fRawData10, 
            fRawData12, fRawData14, fRawData15, fRawData16, fRawData18, fRawData20, fRawData25, fRawData30,
            fRawData35, fRawData40, fRawData50, fRawData55, fRawData60, fRawData65, fRawData70, fRawData80,
            fRawData90]

nfiles = len(fRawData) # 26 or 9 or 16

files = [0] * nfiles
for i in range(0, nfiles):
#    files.append( ROOT.TFile(fRawData[i]))
    files[i] = ROOT.TFile(fRawData[i])

#out = ROOT.TFile("gun_k0L_allgev_FTFP_BERT_90000evt_ILD_l5_v02steel.root", "RECREATE")
#out = ROOT.TFile("gun_k0L_allgev_FTFP_BERT_160000evt_ILD_l5_v02steel.root", "RECREATE")
out = ROOT.TFile("gun_k0L_allgev_FTFP_BERT_260000evt_ILD_l5_v02steel.root", "RECREATE")

# %%
trees = [0] * nfiles

for i in range(0, nfiles):
    trees[i] = files[i].Get("tree")
    
summ = 0
nEntries = [0] * nfiles
for i in range(0, nfiles):
    nEntries[i] = trees[i].GetEntries()
    if (nEntries[i] % 2) > 0:
        nEntries[i] = nEntries[i] - 1
    summ = summ + nEntries[i]
print(summ)
# Out:
# 228042

# %%
# For output file

mc_energy = array('f', [0.0])

energy = array('f', [0.0])
eecal = array('f', [0.0])
ehcal = array('f', [0.0])

nhits = array('i', [0])
nhits_ecal = array('i', [0])
nhits_hcal = array('i', [0])

time = array('f', [0.0])
etime = array('f', [0.0])
htime = array('f', [0.0])

radius = array('f', [0.0])
eradius = array('f', [0.0])
hradius = array('f', [0.0])

elayer = array('f', [0.0])
hlayer = array('f', [0.0])

energy_hit = array('f', [0.0])
energy_hit_ecal = array('f', [0.0])
energy_hit_hcal = array('f', [0.0])

energy_hit_ecal_max = array('f', [0.0])
energy_hit_hcal_max = array('f', [0.0])

n30 = array('i', [0])
n35 = array('i', [0])
n40 = array('i', [0])
n45 = array('i', [0])
n50 = array('i', [0])
n55 = array('i', [0])
n60 = array('i', [0])
n65 = array('i', [0])
n70 = array('i', [0])
n75 = array('i', [0])
n80 = array('i', [0])
nav = array('i', [0])

c30 = array('f', [0.0])
c35 = array('f', [0.0])
c40 = array('f', [0.0])
c45 = array('f', [0.0])
c50 = array('f', [0.0])
c55 = array('f', [0.0])
c60 = array('f', [0.0])
c65 = array('f', [0.0])
c70 = array('f', [0.0])
c75 = array('f', [0.0])
c80 = array('f', [0.0])

muon_energy = array('f', [0.0])
muon_energy_hit = array('f', [0.0])
muon_nhits = array('i', [0])
muon_time = array('f', [0.0])
muon_layer = array('f', [0.0])

# %%
tree = ROOT.TTree('tree', 'tree')

tree.Branch("mc_energy", mc_energy, "mc_energy/F")

tree.Branch("energy", energy, "energy/F")
tree.Branch("eecal", eecal, "eecal/F")
tree.Branch("ehcal", ehcal, "ehcal/F")

tree.Branch("nhits", nhits, "nhits/I")
tree.Branch("nhits_ecal", nhits_ecal, "nhits_ecal/I")
tree.Branch("nhits_hcal", nhits_hcal, "nhits_hcal/I")

tree.Branch("time", time, "time/F")
tree.Branch("etime", etime, "etime/F")
tree.Branch("htime", htime, "htime/F")

tree.Branch("radius", radius, "radius/F")
tree.Branch("eradius", eradius, "eradius/F")
tree.Branch("hradius", hradius, "hradius/F")

tree.Branch("elayer", elayer, "elayer/F")
tree.Branch("hlayer", hlayer, "hlayer/F")

tree.Branch("energy_hit", energy_hit, "energy_hit/F")
tree.Branch("energy_hit_ecal", energy_hit_ecal, "energy_hit_ecal/F")
tree.Branch("energy_hit_hcal", energy_hit_hcal, "energy_hit_hcal/F")

tree.Branch("energy_hit_ecal_max", energy_hit_ecal_max, "energy_hit_ecal_max/F")
tree.Branch("energy_hit_hcal_max", energy_hit_hcal_max, "energy_hit_hcal_max/F")

tree.Branch("n30", n30, "n30/I")
tree.Branch("n35", n35, "n35/I")
tree.Branch("n40", n40, "n40/I")
tree.Branch("n45", n45, "n45/I")
tree.Branch("n50", n50, "n50/I")
tree.Branch("n55", n55, "n55/I")
tree.Branch("n60", n60, "n60/I")
tree.Branch("n65", n65, "n65/I")
tree.Branch("n70", n70, "n70/I")
tree.Branch("n75", n75, "n75/I")
tree.Branch("n80", n80, "n80/I")
tree.Branch("nav", nav, "nav/I")

tree.Branch("c30", c30, "c30/F")
tree.Branch("c35", c35, "c35/F")
tree.Branch("c40", c40, "c40/F")
tree.Branch("c45", c45, "c45/F")
tree.Branch("c50", c50, "c50/F")
tree.Branch("c55", c55, "c55/F")
tree.Branch("c60", c60, "c60/F")
tree.Branch("c65", c65, "c65/F")
tree.Branch("c70", c70, "c70/F")
tree.Branch("c75", c75, "c75/F")
tree.Branch("c80", c80, "c80/F")

tree.Branch("muon_energy", muon_energy, "muon_energy/F")
tree.Branch("muon_energy_hit", muon_energy_hit, "muon_energy_hit/F")
tree.Branch("muon_nhits", muon_nhits, "muon_nhits/I")
tree.Branch("muon_time", muon_time, "muon_time/F")
tree.Branch("muon_layer", muon_layer, "muon_layer/F");

# %%
# For input files

mc_energy_temp = array('f', [0.0])

energy_temp = array('f', [0.0])
eecal_temp = array('f', [0.0])
ehcal_temp = array('f', [0.0])

nhits_temp = array('i', [0])
nhits_ecal_temp = array('i', [0])
nhits_hcal_temp = array('i', [0])

time_temp = array('f', [0.0])
etime_temp = array('f', [0.0])
htime_temp = array('f', [0.0])

radius_temp = array('f', [0.0])
eradius_temp = array('f', [0.0])
hradius_temp = array('f', [0.0])

elayer_temp = array('f', [0.0])
hlayer_temp = array('f', [0.0])

energy_hit_temp = array('f', [0.0])
energy_hit_ecal_temp = array('f', [0.0])
energy_hit_hcal_temp = array('f', [0.0])

energy_hit_ecal_max_temp = array('f', [0.0])
energy_hit_hcal_max_temp = array('f', [0.0])

n30_temp = array('i', [0])
n35_temp = array('i', [0])
n40_temp = array('i', [0])
n45_temp = array('i', [0])
n50_temp = array('i', [0])
n55_temp = array('i', [0])
n60_temp = array('i', [0])
n65_temp = array('i', [0])
n70_temp = array('i', [0])
n75_temp = array('i', [0])
n80_temp = array('i', [0])
nav_temp = array('i', [0 ])

c30_temp = array('f', [0.0])
c35_temp = array('f', [0.0])
c40_temp = array('f', [0.0])
c45_temp = array('f', [0.0])
c50_temp = array('f', [0.0])
c55_temp = array('f', [0.0])
c60_temp = array('f', [0.0])
c65_temp = array('f', [0.0])
c70_temp = array('f', [0.0])
c75_temp = array('f', [0.0])
c80_temp = array('f', [0.0])

muon_energy_temp = array('f', [0.0])
muon_energy_hit_temp = array('f', [0.0])
muon_nhits_temp = array('i', [0])
muon_time_temp = array('f', [0.0])
muon_layer_temp = array('f', [0.0])

# %%
for i in range(0, nfiles):
    trees[i].SetBranchAddress("mc_energy", mc_energy_temp)
    
    trees[i].SetBranchAddress("energy", energy_temp)
    trees[i].SetBranchAddress("eecal", eecal_temp)
    trees[i].SetBranchAddress("ehcal", ehcal_temp)

    trees[i].SetBranchAddress("nhits", nhits_temp)
    trees[i].SetBranchAddress("nhits_ecal", nhits_ecal_temp)
    trees[i].SetBranchAddress("nhits_hcal", nhits_hcal_temp)

    trees[i].SetBranchAddress("time", time_temp)
    trees[i].SetBranchAddress("etime", etime_temp)
    trees[i].SetBranchAddress("htime", htime_temp)

    trees[i].SetBranchAddress("radius", radius_temp)
    trees[i].SetBranchAddress("eradius", eradius_temp)
    trees[i].SetBranchAddress("hradius", hradius_temp)

    trees[i].SetBranchAddress("elayer", elayer_temp)
    trees[i].SetBranchAddress("hlayer", hlayer_temp)

    trees[i].SetBranchAddress("energy_hit", energy_hit_temp)
    trees[i].SetBranchAddress("energy_hit_ecal", energy_hit_ecal_temp)
    trees[i].SetBranchAddress("energy_hit_hcal", energy_hit_hcal_temp)

    trees[i].SetBranchAddress("energy_hit_ecal_max", energy_hit_ecal_max_temp)
    trees[i].SetBranchAddress("energy_hit_hcal_max", energy_hit_hcal_max_temp)

    trees[i].SetBranchAddress("n30", n30_temp)
    trees[i].SetBranchAddress("n35", n35_temp)
    trees[i].SetBranchAddress("n40", n40_temp)
    trees[i].SetBranchAddress("n45", n45_temp)
    trees[i].SetBranchAddress("n50", n50_temp)
    trees[i].SetBranchAddress("n55", n55_temp)
    trees[i].SetBranchAddress("n60", n60_temp)
    trees[i].SetBranchAddress("n65", n65_temp)
    trees[i].SetBranchAddress("n70", n70_temp)
    trees[i].SetBranchAddress("n75", n75_temp)
    trees[i].SetBranchAddress("n80", n80_temp)
    trees[i].SetBranchAddress("nav", nav_temp)

    trees[i].SetBranchAddress("c30", c30_temp)
    trees[i].SetBranchAddress("c35", c35_temp)
    trees[i].SetBranchAddress("c40", c40_temp)
    trees[i].SetBranchAddress("c45", c45_temp)
    trees[i].SetBranchAddress("c50", c50_temp)
    trees[i].SetBranchAddress("c55", c55_temp)
    trees[i].SetBranchAddress("c60", c60_temp)
    trees[i].SetBranchAddress("c65", c65_temp)
    trees[i].SetBranchAddress("c70", c70_temp)
    trees[i].SetBranchAddress("c75", c75_temp)
    trees[i].SetBranchAddress("c80", c80_temp)
    
    trees[i].SetBranchAddress("muon_energy", muon_energy_temp)
    trees[i].SetBranchAddress("muon_energy_hit", muon_energy_hit_temp)
    trees[i].SetBranchAddress("muon_nhits", muon_nhits_temp)
    trees[i].SetBranchAddress("muon_time", muon_time_temp)
    trees[i].SetBranchAddress("muon_layer", muon_layer_temp)

# %%
for i in range(0, nfiles):
    for j in range(0, nEntries[i]):
#    for j in range(0, (nEntries[i] // 2)):
        trees[i].GetEntry(j)
    
#        if ((energy_temp[0] >= 0.9 * mc_energy_temp[0]) and (energy_temp[0] <= 1.1 * mc_energy_temp[0])):
#        if ( (radius_temp[0] <= 500.0) and (eradius_temp[0] <= 500.0) and (hradius_temp[0] <= 500.0) ):
                         
        mc_energy[0] = mc_energy_temp[0]

        energy[0] = energy_temp[0]
        eecal[0] = eecal_temp[0]
        ehcal[0] = ehcal_temp[0]
    
        nhits[0] = nhits_temp[0]
        nhits_ecal[0] = nhits_ecal_temp[0]
        nhits_hcal[0] = nhits_hcal_temp[0]

        time[0] = time_temp[0]
        etime[0] = etime_temp[0]
        htime[0] = htime_temp[0]

        radius[0] = radius_temp[0]
        eradius[0] = eradius_temp[0]
        hradius[0] = hradius_temp[0]

        elayer[0] = elayer_temp[0]
        hlayer[0] = hlayer_temp[0]

        energy_hit[0] = energy_hit_temp[0]
        energy_hit_ecal[0] = energy_hit_ecal_temp[0]
        energy_hit_hcal[0] = energy_hit_hcal_temp[0]

        energy_hit_ecal_max[0] = energy_hit_ecal_max_temp[0]
        energy_hit_hcal_max[0] = energy_hit_hcal_max_temp[0]
        
        n30[0] = n30_temp[0]
        n35[0] = n35_temp[0]
        n40[0] = n40_temp[0]
        n45[0] = n45_temp[0]
        n50[0] = n50_temp[0]
        n55[0] = n55_temp[0]
        n60[0] = n60_temp[0]
        n65[0] = n65_temp[0]
        n70[0] = n70_temp[0]
        n75[0] = n75_temp[0]
        n80[0] = n80_temp[0]
        nav[0] = nav_temp[0]

        c30[0] = c30_temp[0]
        c35[0] = c35_temp[0]
        c40[0] = c40_temp[0]
        c45[0] = c45_temp[0]
        c50[0] = c50_temp[0]
        c55[0] = c55_temp[0]
        c60[0] = c60_temp[0]
        c65[0] = c65_temp[0]
        c70[0] = c70_temp[0]
        c75[0] = c75_temp[0]
        c80[0] = c80_temp[0]
        
        muon_energy[0] = muon_energy_temp[0]
        muon_energy_hit[0] = muon_energy_hit_temp[0]
        muon_nhits[0] = muon_nhits_temp[0]
        muon_time[0] = muon_time_temp[0]
        muon_layer[0] = muon_layer_temp[0]

        tree.Fill()

# %%
tree.Write()
# Out:
# 13460

# %%
out.Close()
